# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense,Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import keras
print(keras.__version__)
# Out:
# 2.10.0

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()

# %%
def prepare_image(file):
    img_path = 'images/'
    img = image.load_img(img_path + file, target_size = (224,224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array,axis=0)
    return tf.keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
from IPython.display import Image
Image(filename='images/orange.jpg',width=450,height=300)

# %%
preprocessed_image = prepare_image('orange.jpg')
predictions = mobile.predict(preprocessed_image)
results =  imagenet_utils.decode_predictions(predictions)
results
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[('n07747607', 'orange', 0.85806763),
#   ('n07749582', 'lemon', 0.13614617),
#   ('n01443537', 'goldfish', 0.0009875916),
#   ('n07716906', 'spaghetti_squash', 0.00084009225),
#   ('n03134739', 'croquet_ball', 0.00068732625)]]

# %%
Image(filename='images/messi.jpg',width=450,height=300)

# %%
preprocessed_image =prepare_image('messi.jpg')
predictions= mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# 1/1 [==============================] - 1s 745ms/step
# [[('n04254680', 'soccer_ball', 0.66337585),
#   ('n04118538', 'rugby_ball', 0.13402432),
#   ('n03888257', 'parachute', 0.041590452),
#   ('n02777292', 'balance_beam', 0.038477905),
#   ('n03379051', 'football_helmet', 0.032140326)]]
